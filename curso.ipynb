# %% [markdown]
# <a href="https://colab.research.google.com/github/wesleyorrr/AND_AL_ONE/blob/main/curso.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Ola mundo")
# Out:
# Ola mundo

# %% [markdown]
# # Variaveis

# %%
# Variaveis Texto
Name = 'Odair'
print(Name)
# Out:
# Odair

# %%
# Variaveis Texto
Sobrenome = 'Oliveira Mendes'
print(Name,Sobrenome)
# Out:
# Odair Oliveira Mendes

# %%
# Variaveis Numericas
Idade = 33
anos = "anos"
print(Name,Sobrenome, Idade, anos)
# Out:
# Odair Oliveira Mendes 33 anos

# %% [markdown]
# # Operadores matematicos
#
# ```
# 1. Soma
# 2. Subtração
# 3. Multiplicação
# 4. Divisão
# 5. Exponeciação
# 6. Resto da Divisão
# 7. Divisão de Chão
#
# ```

# %%
# Soma
1 + 3 + 4
# Out:
# 8

# %%
# Subtração
4 - 4
# Out:
# 0

# %%
# Mutiplicação
5 * 8
# Out:
# 40

# %%
# Divisão

90 / 9
# Out:
# 10.0

# %%
# Exponeciação
2 ** 3 #(2x2x2)
# Out:
# 8

# %%
# Resto da divisão
3 % 4
# Out:
# 3

# %%
# divisão de chão

3 // 4
# Out:
# 0

# %%
# priorização
(2 + 2)* 5
# Out:
# 20
